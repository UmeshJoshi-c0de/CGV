# %% [markdown]
# <a href="https://colab.research.google.com/github/UmeshJoshi-c0de/CGV/blob/main/Line_Drawing_with_DDA_Algorithm_Write_a_program_to_implement_the_DDA_Line_Drawing_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Experiment 1 : Line Drawing with DDA Algorithm:**
#
# **Objective: *(i)* Write a program to implement the DDA Line Drawing Algorithm.**
#
# ***Task 1:* Execute the Program.**
#
# ***Task 2:* Upload on Github**
#
# ***Task 3:* Prepare the Lab Assignment**
#
# ***Task 4:* Submit the Practical Lab-Quiz 1**

# %%
import matplotlib.pyplot as plt

def draw_line_dda(x1, y1, x2, y2):
    # Calculate dx and dy
    dx = x2 - x1
    dy = y2 - y1

    # Calculate the number of steps required
    steps = max(abs(dx), abs(dy))

    # Calculate the increment for each step
    x_increment = dx / float(steps)
    y_increment = dy / float(steps)

    # Starting point
    x = x1
    y = y1

    # Store the points to plot
    x_points = []
    y_points = []

    # Generate points for the line
    for i in range(steps + 1):
        x_points.append(round(x))
        y_points.append(round(y))
        x += x_increment
        y += y_increment

    # Plot the line using matplotlib
    plt.plot(x_points, y_points, marker='o', color='blue')
    plt.title("DDA Line Drawing Algorithm")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.grid(True)
    plt.show()

# Example usage
x1, y1 = 2, 3
x2, y2 = 10, 7
draw_line_dda(x1, y1, x2, y2)
